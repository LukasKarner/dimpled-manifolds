# %%
from utils import *
from models import MnistAEC
from torch.utils.data import DataLoader
from itertools import product

# %%
log_to_stdout()

batch_size = 16
loss_fn = nn.MSELoss()
lr = 0.001
lam = 1.
epochs = 10

device = torch.device('cpu')

# %%
X = torch.linspace(-1, 1, 101)
Y = torch.linspace(-1, 1, 101)
data_2d = torch.tensor(list(product(X, Y)), dtype=X.dtype)
data_2d.unsqueeze_(-1)

M = torch.randn(100,2)
in_place_qr(M)
data = torch.matmul(M, data_2d)
data.squeeze_()
data.unsqueeze_(0)

dataset = torch.utils.data.TensorDataset(data, torch.empty(len(data)))
dataloader = DataLoader(dataset, batch_size, shuffle=True)

# %%
data_2d.size()
# Out:
# torch.Size([10201, 2, 1])

# %%
data.size()
# Out:
# torch.Size([1, 10201, 100])

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(data_2d[:,0], data_2d[:,1], ls='', marker='.')
plt.tight_layout()
plt.show()

# %%
class SimpleAE(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(100, 50),
            nn.ReLU(),
            nn.Linear(50, 20),
            nn.ReLU(),
            nn.Linear(20, 7),
            nn.ReLU(),
            nn.Linear(7, 2),
        )
        self.decoder = nn.Sequential(
            nn.Linear(2, 7),
            nn.ReLU(),
            nn.Linear(7, 20),
            nn.ReLU(),
            nn.Linear(20, 50),
            nn.ReLU(),
            nn.Linear(50, 100),
        )
    
    def forward(self, x):
        e = self.encoder(x)
        d = self.decoder(e)
        return d

# %%
model = SimpleAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
for i in range(epochs):
    logging.info(f'epoch {i + 1}')
    train_iso_ae(dataloader, model, loss_fn, lam, optimizer, device)
    if (i + 1) % 5 == 0:
        test_ae(test_dataloader, model, loss_fn, lam, device)
# Out:
# 2023-01-24 15:00:48,792 INFO: epoch 1

# %%
quit()

# %%
device = torch.device('cpu')
model = MnistAEC().to(device)
loss = nn.MSELoss().to(device)
iso_loss = IsoLoss(100).to(device)

# %%
x = torch.randn(20,1,28,28).to(device)

# %%
model.train()
y = model.encoder(x)
z = model.decoder(y)
l = loss(x,z)

# %%
l.backward(retain_graph=True)

# %%
model.decoder._modules['0'].weight.grad
# Out:
# tensor([[-5.7947e-04,  1.3401e-03, -7.4917e-04,  ...,  9.3910e-04,
#          -2.5995e-03, -1.2876e-03],
#         [-8.2319e-03, -4.3341e-04, -6.9795e-05,  ..., -8.3079e-04,
#          -4.9648e-03,  2.5006e-03],
#         [ 1.6648e-02,  4.1154e-03, -5.3865e-03,  ..., -1.1615e-02,
#          -8.2571e-03, -8.9139e-03],
#         ...,
#         [-7.6473e-03,  1.8258e-03,  1.2507e-02,  ..., -8.4317e-03,
#           4.3672e-03, -1.3073e-03],
#         [ 2.7815e-03,  1.0023e-03, -3.7741e-03,  ..., -6.4813e-03,
#          -2.5669e-03,  6.9393e-04],
#         [-2.7842e-03, -9.5329e-04, -1.1272e-03,  ...,  6.3828e-04,
#           2.2089e-03,  1.8861e-03]])

# %%
y = torch.unsqueeze(y,1)

# %%
model.eval()
decoder_jac = ft.vmap(ft.jacfwd(model.decoder))(y)

# %%
l_iso = iso_loss(decoder_jac)

# %%
l_iso.backward()

# %%
model.decoder._modules['0'].weight.grad
# Out:
# tensor([[-9.8995e-04,  1.3082e-03,  3.5357e-04,  ..., -1.6530e-04,
#          -2.6647e-03, -1.0545e-03],
#         [-7.8494e-03, -4.4789e-04,  1.6478e-05,  ..., -7.9173e-04,
#          -4.5461e-03,  2.5842e-03],
#         [ 1.7414e-02,  3.6374e-03, -5.4578e-03,  ..., -1.1351e-02,
#          -8.1380e-03, -8.5558e-03],
#         ...,
#         [-7.6645e-03,  1.9516e-03,  1.2470e-02,  ..., -8.4922e-03,
#           4.4966e-03, -1.4463e-03],
#         [ 2.1407e-03,  1.0760e-03, -3.7753e-03,  ..., -6.2925e-03,
#          -2.4314e-03,  1.0871e-03],
#         [-2.8230e-03, -9.5626e-04, -1.1624e-03,  ...,  6.5532e-04,
#           2.2369e-03,  1.9304e-03]])
